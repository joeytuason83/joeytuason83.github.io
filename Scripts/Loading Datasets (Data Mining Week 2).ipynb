# %% [markdown]
# # Data Reading
#
# First class exposure on how to read and setup data in Python. Created markdowns, added codes and improve lines to demonstrate familiarity after the Data Mining course has finished.

# %% [markdown]
# ## Load all libraries

# %%
import pandas as pd
import numpy as np
import csv
import json

from io import StringIO #The StringIO module an in-memory file-like object. 

# Useful code to remove unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read CSV
#
# Keynote here is that read_csv does not only read csv files but also defined texts.

# %% [markdown]
# ### Item 1
# Read the created in-memory file `one`and create a DataFrame out of it.

# %%
one = StringIO('''p,    s,   m
1, 2, 3
4, 5, 6
7, 8, 9
''')

# %% [markdown]
# **Your answer below:**

# %%
df = pd.read_csv(one)
df
# Out:
#    p      s     m
# 0  1      2     3
# 1  4      5     6
# 2  7      8     9

# %% [markdown]
# We assume here that p, s and m are column names and row index were not provided.

# %% [markdown]
# ### Item 2
# Read the created in-memory file `two`and create a DataFrame wherein all cells without values in the CSV are assigned as `NaN`.

# %%
two = StringIO('''1, 2, 3
4, 5
7
''')

# %% [markdown]
# **Your answer below:**

# %%
df = pd.read_csv(two, header=None, index_col=False)
df
# Out:
#    0    1    2
# 0  1  2.0  3.0
# 1  4  5.0  NaN
# 2  7  NaN  NaN

# %% [markdown]
# ## Read Excel

# %% [markdown]
# ### Item 3
# Reads `NCR.xlsx` and returns a DataFrame with two columns: 'City, Municipality, and Barangay' and 'Total Population'

# %% [markdown]
# **Your answer below:**

# %%
data = pd.read_excel('NCR.xlsx',skiprows=5,usecols=[1,2])

# Convert to dataframe
df = pd.DataFrame(data)

# Define your column name
df.columns = ['Total Population by City, Municipality and Barangay', 'Total Population']

# Remove the nulls
df_final = df.loc[pd.notnull(df.iloc[:,1]),:]

df_final
# Out:
#      Total Population by City, Municipality and Barangay  Total Population
# 0                               NATIONAL CAPITAL REGION         12877253.0
# 2                                        CITY OF MANILA          1780148.0
# 4                                                 TONDO           631363.0
# 5                                            Barangay 1             1976.0
# 6                                            Barangay 2             1662.0
# ...                                                 ...                ...
# 1766                              North Signal Village             32112.0
# 1767                                         Pinagsama             57343.0
# 1768                                        San Miguel              8590.0
# 1769                                  South Daang Hari             19166.0
# 1770                              South Signal Village             39214.0
#
# [1739 rows x 2 columns]

# %% [markdown]
# ## Read Json File

# %% [markdown]
# ### Item 4
# Read a json file with path `https://raw.githubusercontent.com/domoritz/maps/master/data/iris.json` then creates a Pandas DataFrame.

# %% [markdown]
# **Your answer below:**

# %%
df = pd.read_json('https://raw.githubusercontent.com/domoritz/maps/master/data/iris.json')
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Read Zipped Format File

# %% [markdown]
# ### Item 5
# Read `listings.csv.gz` then creates the Excel file airbnb.xlsx

# %% [markdown]
# **Your answer below:**

# %%
df = pd.read_csv('listings.csv.gz', compression='gzip')
df
# Out:
#             id                           listing_url       scrape_id  \
# 0       600795   https://www.airbnb.com/rooms/600795  20150406154443
# 1      4530027  https://www.airbnb.com/rooms/4530027  20150406154443
# 2       896177   https://www.airbnb.com/rooms/896177  20150406154443
# 3      3770567  https://www.airbnb.com/rooms/3770567  20150406154443
# 4      4292560  https://www.airbnb.com/rooms/4292560  20150406154443
# ...        ...                                   ...             ...
# 18431  1313539  https://www.airbnb.com/rooms/1313539  20150406154443
# 18432   680656   https://www.airbnb.com/rooms/680656  20150406154443
# 18433  5373885  https://www.airbnb.com/rooms/5373885  20150406154443
# 18434   586400   https://www.airbnb.com/rooms/586400  20150406154443
# 18435   415825   https://www.airbnb.com/rooms/415825  20150406154443
#
#       last_scraped                                 name  \
# 0       2015-04-06  London Zone1 LOFT 1Bed/1Lounge flat
# 1       2015-04-07  Double room 20mins to Oxford Street
# 2       2015-04-06   Cosy room for 1 or 2 in Kennington
# 3       2015-04-06        Double Room with large garden
# 4       2015-04-07     Superb 3BR House Notting Hill VP
# ...            ...                                  ...
# 18431   2015-04-07     Liverpool Street Double Room *11
# 18432   2015-04-07   Great Triple Studio, in Hammermith
# 18433   2015-04-07                     Double En-suite
# 18434   2015-04-07  Modern, stylish apartment in Camden
# 18435   2015-04-07       BRIGHT QUIET CAMDEN APARTMENT.
#
#                                                  summary  \
# 0      Really Gorgeous LOFT flat for 1-5 people, near...
# 1      Double room available in a beautifully develop...
# 2                                                    NaN
# 3      A ground floor room in the heart of Islington....
# 4      Fabulous 3 bedroom Mews house in Notting Hill ...
# ...                                                  ...
# 18431  Hello dear visitors and welcome to our Monopol...
# 18432                                                NaN
# 18433      Well furnished double bedroom with attache...
# 18434                                                NaN
# 18435  An apartment on the same Underground line as H...
#
#                                                    space  \
# 0      GREAT VALUE, YET VERY COMFORTABLE FLAT NEAR ZO...
# 1                                                    NaN
# 2      Private room with large windows onto and direc...
# 3                                                    NaN
# 4      This house contains a cosy living room on the ...
# ...                                                  ...
# 18431  Hi, WE HAVE BRIGHT AND SPACIOUS FULLY FURNISHE...
# 18432  Just a 2-minute walk from Hammersmith Tube Sta...
# 18433                                                NaN
# 18434  Our Camden apartment is within close proximity...
# 18435  This apartment is one underground stop from Ki...
#
#                                              description  \
# 0      Really Gorgeous LOFT flat for 1-5 people, near...
# 1      Double room available in a beautifully develop...
# 2      Private room with large windows onto and direc...
# 3      A ground floor room in the heart of Islington....
# 4      Fabulous 3 bedroom Mews house in Notting Hill ...
# ...                                                  ...
# 18431  Hello dear visitors and welcome to our Monopol...
# 18432  Just a 2-minute walk from Hammersmith Tube Sta...
# 18433      Well furnished double bedroom with attache...
# 18434  Our Camden apartment is within close proximity...
# 18435  An apartment on the same Underground line as H...
#
#                                              picture_url   host_id  ...  \
# 0      https://a0.muscache.com/ic/pictures/8253726/36...    485861  ...
# 1      https://a1.muscache.com/ic/pictures/56886040/2...  23486604  ...
# 2      https://a1.muscache.com/ic/pictures/13227237/3...   4777568  ...
# 3      https://a0.muscache.com/ic/pictures/47447139/6...  11255553  ...
# 4      https://a1.muscache.com/ic/pictures/67441108/4...   1432477  ...
# ...                                                  ...       ...  ...
# 18431  https://a2.muscache.com/ic/pictures/63084242/c...   7106582  ...
# 18432  https://a2.muscache.com/ic/pictures/12438816/3...    216660  ...
# 18433  https://a2.muscache.com/ic/pictures/67458346/1...  23211855  ...
# 18434  https://a1.muscache.com/ic/pictures/7303558/35...   2890674  ...
# 18435  https://a1.muscache.com/ic/pictures/4880902/5c...   1302946  ...
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                           9.0                   8.0
# 1                           NaN                   NaN
# 2                          10.0                  10.0
# 3                           NaN                   NaN
# 4                           9.0                   9.0
# ...                         ...                   ...
# 18431                       9.0                   9.0
# 18432                      10.0                  10.0
# 18433                       NaN                   NaN
# 18434                       NaN                   NaN
# 18435                       8.0                   9.0
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             9.0                    8.0                 8.0
# 1                             NaN                    NaN                 NaN
# 2                            10.0                    9.0                10.0
# 3                             NaN                    NaN                 NaN
# 4                             9.0                    9.0                 8.0
# ...                           ...                    ...                 ...
# 18431                         9.0                    9.0                 9.0
# 18432                        10.0                   10.0                10.0
# 18433                         NaN                    NaN                 NaN
# 18434                         NaN                    NaN                 NaN
# 18435                         9.0                    9.0                 9.0
#
#       requires_license license jurisdiction_names  \
# 0                    f     NaN                NaN
# 1                    f     NaN                NaN
# 2                    f     NaN                NaN
# 3                    f     NaN                NaN
# 4                    f     NaN                NaN
# ...                ...     ...                ...
# 18431                f     NaN                NaN
# 18432                f     NaN                NaN
# 18433                f     NaN                NaN
# 18434                f     NaN                NaN
# 18435                f     NaN                NaN
#
#       calculated_host_listings_count reviews_per_month
# 0                                  8               2.1
# 1                                  1               NaN
# 2                                  1               0.4
# 3                                  1               NaN
# 4                                100               1.8
# ...                              ...               ...
# 18431                             10               4.9
# 18432                              9               0.4
# 18433                              3               NaN
# 18434                              1               NaN
# 18435                              2               0.4
#
# [18436 rows x 68 columns]

# %%
# Save to excel
df.to_excel("airbnb.xlsx")
