# %%
# !pip install -q tabula-py
import tabula

import warnings
warnings.filterwarnings("ignore")

# %%
import tabula
pdf_path = "2022NLEOVRegVoters.pdf"

dfs = tabula.read_pdf(pdf_path, stream=True)

print(len(dfs))
dfs[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 1
#           TYPE OF ASIA PACIFIC JURISDICTION   FEMALE     MALE LANDBASED  \
# 0                                       NaN      NaN      NaN       NaN
# 1                       BANGKOK PE THAILAND   6714.0   4006.0    10,720
# 2                       BEIJING PE MONGOLIA      8.0      9.0        17
# 3                PEOPLE'S REPUBLIC OF CHINA    563.0    268.0       831
# 4        BRUNEI PE NEGARA BRUNEI DARUSSALAM   6550.0   5738.0    12,288
# 5                     CANBERRA PE AUSTRALIA   3870.0   2526.0     6,396
# 6                                   VANUATU      3.0     14.0        17
# 7      CHONGQING PEOPLE'S REPUBLIC OF CHINA    112.0     77.0       189
# 8                                       PCG      NaN      NaN       NaN
# 9                        DHAKA PE SRI LANKA    170.0     11.0       181
# 10                               BANGLADESH    257.0    129.0       386
# ...
